# %%
# %%bigquery
# CREATE SCHEMA IF NOT EXISTS `airports`
# OPTIONS (
#   location = 'US',
#   description = 'US Airport Data'
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# LOAD DATA INTO `qwiklabs-gcp-01-4b0fd1e23a0f.airports.airport_data`
# FROM FILES (
#   format = 'CSV',
#   uris = ['gs://labs.roitraining.com/data-to-ai-workshop/airports.csv']
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
from typing import Optional, List, Dict
import datetime

# BigQuery and Vertex AI (for Gemini) imports
from google.cloud import bigquery
import vertexai
from vertexai.generative_models import GenerativeModel

def generate_weather_alert(
    project_id: str,
    location: str,
    forecast_period: Dict[str, str]
) -> Optional[str]:
    """
    Generates a weather alert using the Gemini API based on a forecast period.

    Args:
        project_id: Your Google Cloud project ID.
        location: The GCP region for your project (e.g., "us-central1").
        forecast_period: A dictionary containing weather data for one period.

    Returns:
        A string containing the generated weather alert, or None on error.
    """
    # Initialize Vertex AI SDK
    vertexai.init(project=project_id, location=location)

    # --- Prompt construction, mirroring your SQL CONCAT logic ---
    prompt = (
        "Create a concise, one-sentence weather alert for an airport based on the "
        "following information:\n"
        f"- Temperature: {forecast_period.get('temperature')}°{forecast_period.get('temperatureUnit')}\n"
        f"- Wind: {forecast_period.get('windSpeed')} from the {forecast_period.get('windDirection')}\n"
        f"- Conditions: {forecast_period.get('shortForecast')}\n"
        f"- Detailed Outlook: {forecast_period.get('detailedForecast')}"
    )

    model = GenerativeModel("gemini-2.0-flash")

    generation_config = {
        "temperature": 0.2,
        "max_output_tokens": 256,
    }

    print("  -> Sending prompt to Gemini...")
    try:
        response = model.generate_content([prompt], generation_config=generation_config)
        return response.candidates[0].content.parts[0].text.strip()
    except Exception as e:
        print(f"  -> Error generating text with Gemini: {e}")
        return None

def get_extended_weather_forecast(lat: float, lon: float) -> Optional[List[Dict[str, str]]]:
    """
    Fetch the extended weather forecast from the U.S. National Weather Service (NWS) API
    based on a given latitude and longitude.
    """
    headers = {
        'User-Agent': 'MyWeatherApp (youremail@example.com)',
        'Accept': 'application/geo+json'
    }

    points_url = f"https://api.weather.gov/points/{lat},{lon}"
    try:
        response = requests.get(points_url, headers=headers, timeout=15)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching points data for {lat},{lon}: {e}")
        return None

    points_data = response.json()
    forecast_url = points_data['properties'].get('forecast')
    if not forecast_url:
        print(f"Forecast URL not found in response for {lat},{lon}.")
        return None

    try:
        forecast_response = requests.get(forecast_url, headers=headers, timeout=15)
        forecast_response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching forecast for {lat},{lon}: {e}")
        return None

    forecast_data = forecast_response.json()
    periods = forecast_data['properties'].get('periods', [])

    if not periods:
        return []

    extended_forecast = []
    for period in periods:
        extended_forecast.append({
            'name': period.get('name'),
            'startTime': period.get('startTime'),
            'temperature': str(period.get('temperature')),
            'temperatureUnit': period.get('temperatureUnit'),
            'windSpeed': period.get('windSpeed'),
            'windDirection': period.get('windDirection'),
            'shortForecast': period.get('shortForecast'),
            'detailedForecast': period.get('detailedForecast')
        })
    return extended_forecast

def load_results_to_bigquery(client: bigquery.Client, project_id: str, dataset_id: str, table_id: str, data: List[Dict]):
    """
    Loads data into a BigQuery table using CREATE OR REPLACE logic.
    """
    if not data:
        print("No data to load to BigQuery.")
        return

    table_ref = f"{project_id}.{dataset_id}.{table_id}"
    print(f"\nAttempting to load {len(data)} records into BigQuery table: {table_ref}")

    # Define the schema for the destination table, including new fields
    schema = [
        bigquery.SchemaField("airport_name", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("type", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("iso_region", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("municipality", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("latitude", "FLOAT64", mode="NULLABLE"),
        bigquery.SchemaField("longitude", "FLOAT64", mode="NULLABLE"),
        bigquery.SchemaField("forecast_period", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("temperature", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("temperature_unit", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("wind_speed", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("wind_direction", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("short_forecast", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("gemini_alert", "STRING", mode="NULLABLE"),
        bigquery.SchemaField("processing_timestamp", "TIMESTAMP", mode="REQUIRED"),
    ]

    # Configure the load job
    job_config = bigquery.LoadJobConfig(
        schema=schema,
        # This disposition creates the table if it doesn't exist,
        # or overwrites it completely if it does.
        write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,
    )

    try:
        load_job = client.load_table_from_json(data, table_ref, job_config=job_config)
        load_job.result() # Wait for the job to complete
        print(f"Successfully created/replaced table {table_ref} with {load_job.output_rows} rows.")
    except Exception as e:
        print(f"Failed to load data to BigQuery: {e}")

def get_weather_for_airports(project_id: str, location: str, dataset_id: str, source_table_id: str, dest_table_id: str):
    """
    Queries airports, fetches weather, generates alerts, and loads results to BigQuery.
    """
    client = bigquery.Client(project=project_id)
    results_to_load = []

    # Updated query to include new columns and use updated lat/lon names
    query = f"""
        SELECT
            type,
            name as airport_name,
            iso_region,
            municipality,
            latitude_deg as lat,
            longitude_deg as lon
        FROM
            `{project_id}.{dataset_id}.{source_table_id}`
        WHERE type = 'large_airport' AND iso_country = 'US'
    """
    print(f"Running query on BigQuery table: {project_id}.{dataset_id}.{source_table_id}")

    try:
        query_job = client.query(query)
        rows = query_job.result()
    except Exception as e:
        print(f"An error occurred with the BigQuery query: {e}")
        return

    for row in rows:
        airport_name, lat, lon = row.airport_name, row.lat, row.lon
        print("-" * 50)
        print(f"Processing: {airport_name} (Lat: {lat}, Lon: {lon})")

        forecast = get_extended_weather_forecast(lat=lat, lon=lon)

        if forecast:
            current_forecast = forecast[0]
            print(f"  -> Current Weather: {current_forecast['shortForecast']} at {current_forecast['temperature']}°{current_forecast['temperatureUnit']}")

            alert = generate_weather_alert(
                project_id=project_id,
                location=location,
                forecast_period=current_forecast
            )
            if alert:
                print(f"  -> Gemini Alert: {alert}")

            # Prepare the record to be loaded into BigQuery, including new fields
            record = {
                "airport_name": row.airport_name,
                "type": row.type,
                "iso_region": row.iso_region,
                "municipality": row.municipality,
                "latitude": lat,
                "longitude": lon,
                "forecast_period": current_forecast.get("name"),
                "temperature": current_forecast.get("temperature"),
                "temperature_unit": current_forecast.get("temperatureUnit"),
                "wind_speed": current_forecast.get("windSpeed"),
                "wind_direction": current_forecast.get("windDirection"),
                "short_forecast": current_forecast.get("shortForecast"),
                "gemini_alert": alert,
                "processing_timestamp": datetime.datetime.now(datetime.timezone.utc).isoformat(),
            }
            results_to_load.append(record)
        else:
            print("  -> Could not retrieve weather forecast.")

    # After processing all airports, load the collected data into BigQuery
    load_results_to_bigquery(
        client=client,
        project_id=project_id,
        dataset_id=dataset_id,
        table_id=dest_table_id,
        data=results_to_load
    )


if __name__ == "__main__":
    # --- CONFIGURE THESE VALUES ---
    BQ_PROJECT_ID = "qwiklabs-gcp-01-4b0fd1e23a0f"
    GCP_LOCATION = "us-central1"
    BQ_DATASET_ID = "airports"
    BQ_SOURCE_TABLE_ID = "airport_data"
    # This new table will be created or replaced each time the script runs
    BQ_DESTINATION_TABLE_ID = "airport_weather_alerts"

    get_weather_for_airports(
        project_id=BQ_PROJECT_ID,
        location=GCP_LOCATION,
        dataset_id=BQ_DATASET_ID,
        source_table_id=BQ_SOURCE_TABLE_ID,
        dest_table_id=BQ_DESTINATION_TABLE_ID,
    )
# Out:
# Running query on BigQuery table: qwiklabs-gcp-01-4b0fd1e23a0f.airports.airport_data
# --------------------------------------------------
# Processing: Albuquerque International Sunport (Lat: 35.039976, Lon: -106.608925)
#   -> Current Weather: Partly Sunny then Scattered Showers And Thunderstorms at 81°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Expect scattered showers and thunderstorms after 3 PM with a high of 81°F and winds from the south at 5-15 mph.**
# --------------------------------------------------
# Processing: Joint Base Andrews (Lat: 38.810799, Lon: -76.866997)
#   -> Current Weather: Sunny at 88°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Alert: Sunny skies and moderate southwest winds with gusts up to 22 mph expected; exercise caution during taxi and takeoff.**
# --------------------------------------------------
# Processing: Hartsfield Jackson Atlanta International Airport (Lat: 33.6367, Lon: -84.428101)
#   -> Current Weather: Sunny at 92°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **High temperature advisory: Expect sunny skies and 92°F with light southwest winds.**
# --------------------------------------------------
# Processing: Austin Bergstrom International Airport (Lat: 30.197535, Lon: -97.662015)
#   -> Current Weather: Mostly Sunny at 101°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Excessive Heat Warning: Airport experiencing mostly sunny conditions with a high of 101°F and heat index values up to 102, accompanied by a south wind of 5 to 15 mph.**
# --------------------------------------------------
# Processing: Bradley International Airport (Lat: 41.93851, Lon: -72.688066)
#   -> Current Weather: Mostly Sunny at 83°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Mostly sunny conditions with a high of 83°F and a south wind of 10-15 mph.**
# --------------------------------------------------
# Processing: Nashville International Airport (Lat: 36.1245, Lon: -86.6782)
#   -> Current Weather: Mostly Sunny then Chance Showers And Thunderstorms at 95°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: High of 95°F, SW winds 10 mph gusting to 20 mph, mostly sunny with a 40% chance of showers and thunderstorms after 4 PM.**
# --------------------------------------------------
# Processing: Logan International Airport (Lat: 42.36197, Lon: -71.0079)
#   -> Current Weather: Mostly Sunny at 83°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Moderate south winds of 14-20 mph are expected at the airport today with mostly sunny skies and a high of 83°F.**
# --------------------------------------------------
# Processing: Buffalo Niagara International Airport (Lat: 42.940498, Lon: -78.732201)
#   -> Current Weather: Mostly Sunny at 76°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Expect mostly sunny skies with strong southwest winds 20-24 mph, gusting to 47 mph, near 76°F.**
# --------------------------------------------------
# Processing: Baltimore/Washington International Thurgood Marshall Airport (Lat: 39.1754, Lon: -76.668297)
#   -> Current Weather: Sunny at 88°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Sunny skies, 88°F, with a southwest wind 6-15 mph gusting to 21 mph; exercise caution for potential wind shear.**
# --------------------------------------------------
# Processing: Cleveland Hopkins International Airport (Lat: 41.411701, Lon: -81.8498)
#   -> Current Weather: Mostly Sunny at 79°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Moderate gusts up to 33 mph expected at the airport; exercise caution during taxi and takeoff.**
# --------------------------------------------------
# Processing: Charlotte Douglas International Airport (Lat: 35.2140007019043, Lon: -80.94309997558594)
#   -> Current Weather: Sunny at 90°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **High temperature advisory: 90°F, sunny skies, and light southwest winds expected at the airport.**
# --------------------------------------------------
# Processing: John Glenn Columbus International Airport (Lat: 39.998001, Lon: -82.891899)
#   -> Current Weather: Slight Chance Rain Showers at 83°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Expect a slight chance of rain showers after 2 PM with southwest winds around 18 mph, gusting to 33 mph.**
# --------------------------------------------------
# Processing: Cincinnati Northern Kentucky International Airport (Lat: 39.048801, Lon: -84.667801)
#   -> Current Weather: Slight Chance Rain Showers at 82°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Slight chance of rain showers after 2 PM; expect mostly sunny skies with a high of 82°F and a 15 mph west wind.**
# --------------------------------------------------
# Processing: Ronald Reagan Washington National Airport (Lat: 38.8521, Lon: -77.037697)
#   -> Current Weather: Sunny at 90°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **High temperature and gusty southwest winds expected; exercise caution during ground operations.**
# --------------------------------------------------
# Processing: Denver International Airport (Lat: 39.861698150635, Lon: -104.672996521)
#   -> Current Weather: Areas Of Smoke at 71°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Weather Alert: Areas of smoke and gusty ESE winds up to 18 mph may affect airport operations.**
# --------------------------------------------------
# Processing: Dallas Fort Worth International Airport (Lat: 32.896801, Lon: -97.038002)
#   -> Current Weather: Partly Sunny then Slight Chance Showers And Thunderstorms at 101°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Heat Advisory: High of 101°F, heat index 105, SSW winds 10 mph, and a slight chance of afternoon thunderstorms.**
# --------------------------------------------------
# Processing: Detroit Metropolitan Wayne County Airport (Lat: 42.21377, Lon: -83.353786)
#   -> Current Weather: Mostly Sunny at 73°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Moderate gusts up to 37 mph expected this afternoon; otherwise, mostly sunny with WSW winds 17-23 mph.**
# --------------------------------------------------
# Processing: Newark Liberty International Airport (Lat: 40.692501, Lon: -74.168701)
#   -> Current Weather: Mostly Sunny at 88°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Mostly sunny, 88°F, southwest wind 8-14 mph; expect routine operations.**
# --------------------------------------------------
# Processing: Fort Lauderdale Hollywood International Airport (Lat: 26.072599, Lon: -80.152702)
#   -> Current Weather: Showers And Thunderstorms Likely at 89°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Alert: Expect likely showers and thunderstorms with a high of 89°F (heat index 101) and a 90% chance of precipitation, impacting operations.**
# --------------------------------------------------
# Processing: Washington Dulles International Airport (Lat: 38.9445, Lon: -77.455803)
#   -> Current Weather: Sunny at 88°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Sunny skies, 88°F, with a southwest wind 6-15 mph, gusting to 24 mph.**
# --------------------------------------------------
# Processing: George Bush Intercontinental Houston Airport (Lat: 29.984399795532227, Lon: -95.34140014648438)
#   -> Current Weather: Mostly Sunny at 95°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Heat Advisory in effect: Expect a high of 95°F with a heat index up to 102 under mostly sunny skies; exercise caution.**
# --------------------------------------------------
# Processing: Indianapolis International Airport (Lat: 39.7173, Lon: -86.294403)
#   -> Current Weather: Partly Sunny at 75°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Moderate wind gusts up to 23 mph expected at the airport; exercise caution during taxi and takeoff.**
# --------------------------------------------------
# Processing: Jacksonville International Airport (Lat: 30.492469, Lon: -81.687813)
#   -> Current Weather: Sunny at 91°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **High temperature alert: Expect 91°F with sunny skies and gusty northeast winds up to 20 mph.**
# --------------------------------------------------
# Processing: John F Kennedy International Airport (Lat: 40.639447, Lon: -73.779317)
#   -> Current Weather: Sunny at 81°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Moderate south winds of 10-21 mph are present under sunny skies; exercise caution during taxi and takeoff.**
# --------------------------------------------------
# Processing: Harry Reid International Airport (Lat: 36.083361, Lon: -115.151817)
#   -> Current Weather: Mostly Sunny then Chance Showers And Thunderstorms at 96°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Heat Advisory: High of 96°F with a 40% chance of afternoon showers and thunderstorms; exercise caution.**
# --------------------------------------------------
# Processing: Los Angeles International Airport (Lat: 33.942501, Lon: -118.407997)
#   -> Current Weather: Patchy Fog at 65°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Patchy fog reported; expect low visibility and light southwest winds around 5 mph, with cloudy skies and a low of 65°F.**
# --------------------------------------------------
# Processing: LaGuardia Airport (Lat: 40.777199, Lon: -73.872597)
#   -> Current Weather: Mostly Sunny at 84°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Mostly sunny, 84°F, with a south wind of 10-15 mph.**
# --------------------------------------------------
# Processing: Kansas City International Airport (Lat: 39.2976, Lon: -94.713898)
#   -> Current Weather: Chance Rain Showers at 67°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Chance of rain showers before 4 PM; expect mostly cloudy skies and a WNW wind at 9 mph.**
# --------------------------------------------------
# Processing: Orlando International Airport (Lat: 28.429399490356445, Lon: -81.30899810791016)
#   -> Current Weather: Chance Showers And Thunderstorms at 91°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Alert: High temperature of 91°F, ENE winds 10-15 mph with gusts to 20 mph, and a 50% chance of showers and thunderstorms.**
# --------------------------------------------------
# Processing: Chicago Midway International Airport (Lat: 41.785999, Lon: -87.752403)
#   -> Current Weather: Mostly Sunny at 65°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Moderate wind shear risk: Expect gusty westerly winds of 15-20 mph, with gusts up to 40 mph, under mostly sunny skies.**
# --------------------------------------------------
# Processing: Memphis International Airport (Lat: 35.0424, Lon: -89.9767)
#   -> Current Weather: Mostly Sunny at 96°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Heat Advisory: Airport experiencing high temperatures of 96°F with a WSW wind of 10 mph under mostly sunny skies.**
# --------------------------------------------------
# Processing: Miami International Airport (Lat: 25.79319953918457, Lon: -80.29060363769531)
#   -> Current Weather: Showers And Thunderstorms Likely at 88°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Showers and thunderstorms likely with a high of 88°F, heat index near 100, and southwest winds at 6 mph; expect significant rainfall.**
# --------------------------------------------------
# Processing: General Mitchell International Airport (Lat: 42.947201, Lon: -87.896599)
#   -> Current Weather: Scattered Rain Showers then Partly Sunny at 63°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Expect scattered rain showers ending by 11 AM, then partly sunny with gusty west winds up to 40 mph.**
# --------------------------------------------------
# Processing: Minneapolis–Saint Paul International Airport / Wold–Chamberlain Field (Lat: 44.880081, Lon: -93.221741)
#   -> Current Weather: Scattered Rain Showers at 59°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Expect scattered rain showers and gusty WNW winds (15-20 mph, gusts to 30 mph) at the airport today.**
# --------------------------------------------------
# Processing: Louis Armstrong New Orleans International Airport (Lat: 29.993401, Lon: -90.258003)
#   -> Current Weather: Sunny at 94°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: High temperature of 94°F expected today with light southeast winds and sunny skies.**
# --------------------------------------------------
# Processing: San Francisco Bay Oakland International Airport (Lat: 37.720085, Lon: -122.221184)
#   -> Current Weather: Mostly Sunny at 70°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Mostly sunny conditions with WSW winds 8-15 mph, gusting to 21 mph, and temperatures near 70°F.**
# --------------------------------------------------
# Processing: Will Rogers World Airport (Lat: 35.393388, Lon: -97.598248)
#   -> Current Weather: Cloudy then Slight Chance Showers And Thunderstorms at 75°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Slight chance of afternoon showers/thunderstorms with NE winds 14-17 mph, gusting to 26 mph, expect cloudy skies and a high of 75°F.**
# --------------------------------------------------
# Processing: Eppley Airfield (Lat: 41.3032, Lon: -95.894096)
#   -> Current Weather: Mostly Sunny at 67°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Gusty winds up to 23 mph expected; exercise caution during taxi and takeoff.**
# --------------------------------------------------
# Processing: Ontario International Airport (Lat: 34.056, Lon: -117.600998)
#   -> Current Weather: Sunny at 93°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Alert: High temperature of 93°F and possible gusty winds up to 20 mph from the SW expected today.**
# --------------------------------------------------
# Processing: Chicago O'Hare International Airport (Lat: 41.9786, Lon: -87.9048)
#   -> Current Weather: Mostly Sunny at 64°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Gusty winds up to 40 mph expected; exercise caution during taxi and takeoff.**
# --------------------------------------------------
# Processing: Norfolk International Airport (Lat: 36.895341, Lon: -76.201)
#   -> Current Weather: Sunny at 90°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **High temperature advisory: Expect sunny skies, 90°F, with SW winds 9-14 mph; potential for heat-related impacts.**
# --------------------------------------------------
# Processing: Palm Beach International Airport (Lat: 26.683201, Lon: -80.095596)
#   -> Current Weather: Showers And Thunderstorms Likely at 90°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Alert: Expect showers and thunderstorms likely with a high of 90°F and light easterly winds.**
# --------------------------------------------------
# Processing: Portland International Airport (Lat: 45.588699, Lon: -122.598)
#   -> Current Weather: Slight Chance Showers And Thunderstorms at 87°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Slight chance of showers and thunderstorms, 87°F, NW wind 2-6 mph.**
# --------------------------------------------------
# Processing: Philadelphia International Airport (Lat: 39.871899, Lon: -75.241096)
#   -> Current Weather: Sunny at 86°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Sunny skies, 86°F, with a southwest wind of 5-10 mph; expect similar conditions throughout the day.**
# --------------------------------------------------
# Processing: Phoenix Sky Harbor International Airport (Lat: 33.435302, Lon: -112.005905)
#   -> Current Weather: Mostly Sunny then Slight Chance Showers And Thunderstorms at 97°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Heat advisory in effect: High of 97°F with a slight chance of afternoon showers and thunderstorms after 2 PM; exercise caution.**
# --------------------------------------------------
# Processing: Pittsburgh International Airport (Lat: 40.491501, Lon: -80.232903)
#   -> Current Weather: Mostly Sunny at 81°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Gusty winds up to 28 mph possible; exercise caution during taxi and takeoff.**
# --------------------------------------------------
# Processing: Theodore Francis Green State Airport (Lat: 41.725038, Lon: -71.425668)
#   -> Current Weather: Sunny at 81°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Moderate south winds (14-17 mph) are present under sunny skies with a temperature of 81°F.**
# --------------------------------------------------
# Processing: Portland International Jetport (Lat: 43.646198, Lon: -70.309303)
#   -> Current Weather: Patchy Fog at 59°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Alert: Patchy fog and a chance of rain showers expected between 2 AM and 4 AM, with continued patchy fog and a low of 59°F, S wind 10 mph.**
# --------------------------------------------------
# Processing: Raleigh Durham International Airport (Lat: 35.877602, Lon: -78.787498)
#   -> Current Weather: Sunny at 90°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **High temperature advisory: 90°F, light SW winds, sunny conditions at the airport.**
# --------------------------------------------------
# Processing: Richmond International Airport (Lat: 37.505199, Lon: -77.319702)
#   -> Current Weather: Sunny at 90°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **High temperature and gusty southwest winds expected at the airport today; exercise caution.**
# --------------------------------------------------
# Processing: Reno Tahoe International Airport (Lat: 39.4991, Lon: -119.767998)
#   -> Current Weather: Patchy Smoke at 90°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: High temperature (90°F) and patchy smoke expected between 11 AM and 1 PM with a west wind of 5-10 mph.**
# --------------------------------------------------
# Processing: Southwest Florida International Airport (Lat: 26.53619956970215, Lon: -81.75520324707031)
#   -> Current Weather: Chance Showers And Thunderstorms at 90°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Alert: High of 90°F, SSE winds at 7 mph, chance of thunderstorms with heavy rain and possible heat index of 102.**
# --------------------------------------------------
# Processing: San Diego International Airport (Lat: 32.7336006165, Lon: -117.190002441)
#   -> Current Weather: Patchy Fog then Partly Sunny at 78°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: Expect patchy fog before 11 AM, then partly sunny skies with a high of 78°F and NW winds 5-10 mph.
# --------------------------------------------------
# Processing: San Antonio International Airport (Lat: 29.533701, Lon: -98.469803)
#   -> Current Weather: Mostly Sunny at 99°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Heat Advisory: High temperatures near 99°F with a heat index of 100, exercise caution during outdoor activities.**
# --------------------------------------------------
# Processing: Savannah Hilton Head International Airport (Lat: 32.127602, Lon: -81.202103)
#   -> Current Weather: Sunny at 91°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Heat advisory: High of 91°F with light easterly winds; exercise caution due to elevated temperatures.**
# --------------------------------------------------
# Processing: Louisville Muhammad Ali International Airport (Lat: 38.1744, Lon: -85.736)
#   -> Current Weather: Mostly Sunny at 85°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Alert: Expect mostly sunny skies, 85°F, with a 13 mph west wind and a slight chance of minimal rainfall.**
# --------------------------------------------------
# Processing: Seattle–Tacoma International Airport (Lat: 47.447943, Lon: -122.310276)
#   -> Current Weather: Haze at 78°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Haze reported, visibility reduced; expect mostly sunny skies with light westerly winds and a high of 78°F.**
# --------------------------------------------------
# Processing: Orlando Sanford International Airport (Lat: 28.777599334716797, Lon: -81.23750305175781)
#   -> Current Weather: Chance Showers And Thunderstorms at 90°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Alert: Expect chance showers and thunderstorms with a high of 90°F and gusty NE winds up to 25 mph.**
# --------------------------------------------------
# Processing: San Francisco International Airport (Lat: 37.619806, Lon: -122.374821)
#   -> Current Weather: Mostly Sunny at 71°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Moderate west winds gusting to 23 mph possible this afternoon; otherwise, mostly sunny skies and temperatures near 70°F expected.**
# --------------------------------------------------
# Processing: Norman Y. Mineta San Jose International Airport (Lat: 37.362452, Lon: -121.929188)
#   -> Current Weather: Mostly Sunny at 75°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: Airport weather alert: Mostly sunny, 75°F, NW winds 5-12 mph gusting to 20 mph possible this afternoon.
# --------------------------------------------------
# Processing: Salt Lake City International Airport (Lat: 40.78886, Lon: -111.979866)
#   -> Current Weather: Mostly Sunny then Slight Chance Showers And Thunderstorms at 87°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Mostly sunny with a slight chance of afternoon showers and thunderstorms, high of 87°F, WNW winds at 7 mph.**
# --------------------------------------------------
# Processing: Sacramento International Airport (Lat: 38.6954, Lon: -121.591003)
#   -> Current Weather: Sunny at 88°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Sunny skies, 88°F, with a south wind 6-10 mph; expect similar conditions throughout the day.**
# --------------------------------------------------
# Processing: John Wayne Orange County International Airport (Lat: 33.675701, Lon: -117.867996)
#   -> Current Weather: Patchy Fog then Mostly Sunny at 81°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Expect patchy fog before 11 AM, transitioning to mostly sunny skies with southwest winds 5-10 mph gusting to 20 mph, and a high of 81°F.**
# --------------------------------------------------
# Processing: Sarasota Bradenton International Airport (Lat: 27.394631, Lon: -82.554359)
#   -> Current Weather: Scattered Showers And Thunderstorms at 91°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Alert: Scattered showers and thunderstorms with possible heavy rain and a heat index of 104°F are expected; exercise caution.**
# --------------------------------------------------
# Processing: St. Louis Lambert International Airport (Lat: 38.748697, Lon: -90.370003)
#   -> Current Weather: Mostly Cloudy at 74°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Moderate gusts up to 21 mph expected at the airport; otherwise, mostly cloudy with a temperature of 74°F and NW winds at 13 mph.**
# --------------------------------------------------
# Processing: Syracuse Hancock International Airport (Lat: 43.11119842529297, Lon: -76.1063003540039)
#   -> Current Weather: Sunny at 80°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Sunny skies, 80°F, with a south wind 10-17 mph.**
# --------------------------------------------------
# Processing: Tampa International Airport (Lat: 27.9755, Lon: -82.533203)
#   -> Current Weather: Partly Sunny then Scattered Showers And Thunderstorms at 92°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: High of 92°F with scattered showers and thunderstorms likely after 1 PM, heat index up to 101°F, and a 40% chance of precipitation.**
# --------------------------------------------------
# Processing: Tulsa International Airport (Lat: 36.19839859008789, Lon: -95.88809967041016)
#   -> Current Weather: Chance Showers And Thunderstorms at 74°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Alert: Expect chance showers and thunderstorms with gusty NE winds up to 30 mph today.**
# --------------------------------------------------
# Processing: Ted Stevens Anchorage International Airport (Lat: 61.179004, Lon: -149.992561)
#   -> Current Weather: Light Rain Likely at 62°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: Light rain likely before 4 PM; expect partly sunny skies and calm winds with a high of 62°F.
# --------------------------------------------------
# Processing: Daniel K Inouye International Airport (Lat: 21.32062, Lon: -157.924228)
#   -> Current Weather: Sunny at 84°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **Airport Weather Alert: Sunny skies, temperature 84°F, with ENE winds 8-13 mph.**
# --------------------------------------------------
# Processing: Kahului International Airport (Lat: 20.896263, Lon: -156.431837)
#   -> Current Weather: Sunny at 90°F
#   -> Sending prompt to Gemini...
#   -> Gemini Alert: **High temperature alert: Expect sunny conditions with a high of 90°F and ENE winds 6-14 mph, gusting to 18 mph, potentially impacting aircraft performance.**
#
# Attempting to load 71 records into BigQuery table: qwiklabs-gcp-01-4b0fd1e23a0f.airports.airport_weather_alerts
# Successfully created/replaced table qwiklabs-gcp-01-4b0fd1e23a0f.airports.airport_weather_alerts with 71 rows.
